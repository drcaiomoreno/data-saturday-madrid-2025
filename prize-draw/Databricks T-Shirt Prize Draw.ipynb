# %% [markdown]
# Form: https://forms.gle/vabxVMEfA3AKPpgz5

# %% [markdown]
# AI Prompt: Write me a code to give me a Random Number from 1 to 4.

# %%
from pyspark.sql.functions import uniform

df = spark.range(1).select(uniform(4, 10).alias("random_number"))
display(df)
